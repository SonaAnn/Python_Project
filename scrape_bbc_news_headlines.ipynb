# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape and display top news headlines
def scrape_bbc_news_headlines():
    url = 'https://www.bbc.com/news'

    # Send an HTTP GET request to the URL
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        headline_elements = soup.find_all(class_='gs-c-promo-heading')
        
        # Print the headlines
        print("BBC News Headlines:")
        for idx, element in enumerate(headline_elements, start=1):
            headline_text = element.get_text(strip=True)
            print(f"{idx}. {headline_text}")
        
        # Create or open a CSV file to write headlines
        with open('bbc_news_headlines_1.csv', 'w', newline='', encoding='utf-8') as csvfile:
            # Create a CSV writer
            csv_writer = csv.writer(csvfile)
            
            # Write a header row to the CSV file
            csv_writer.writerow(["Index", "Headline"])

            # Extract and save the headlines to the CSV file
            for idx, element in enumerate(headline_elements, start=1):
                headline_text = element.get_text(strip=True)
                csv_writer.writerow([idx, headline_text])
                
        print("Headlines written to 'bbc_news_headlines_1.csv'")
    else:
        print("Failed to retrieve the web page. Status code:", response.status_code)

# Call the function to scrape and print headlines, and then create the CSV file
scrape_bbc_news_headlines()
# Out:
# BBC News Headlines:
# 1. LiveLiveLachlan Murdoch replaces father Rupert as chair of Fox and News Corp
# 2. LiveLiveLachlan Murdoch replaces father Rupert as chair of Fox and News Corp
# 3. India suspends visas for Canadians as row escalates
# 4. LiveLiveZelensky lays wreath at Pentagon's 9/11 memorial
# 5. How Norway outstrips US on Ukraine spending
# 6. 'I don't care about sportswashing' - Saudi prince
# 7. Game of Thrones author sues ChatGPT-owner OpenAI
# 8. Murdoch's eldest son Lachlan to head Fox and News Corp
# 9. Google accused of sending motorist off bridge
# 10. South Korea raids US military bases in drugs probe
# 11. Poland no longer supplying weapons to Ukraine - PM
# 12. Video 24 secondsCharles gives French toast at star-studded banquet
# 13. Poland no longer supplying weapons to Ukraine - PM
# 14. Video 24 secondsCharles gives French toast at star-studded banquet
# 15. Fresh gunfire reported in Karabakh despite truce
# ...
